# %%
value=
# Out:
#   Cell In[1], line 1
#     value=
#           ^
# SyntaxError: invalid syntax

# %%
value=[2,4,7,9]
print(list[3])
# Out:
# list[3]

# %%
value=[22,33,44,55]
print(list[5])
# Out:
# list[5]

# %%
a=int(input("Enter a positive integer:"))
if a<=0:
    raise ValueError("This is a not a positive number!")
except ValueError as ve:
print(ve)
# Out:
#   Cell In[7], line 4
#     except ValueError as ve:
#     ^
# SyntaxError: invalid syntax

# %%
try:
    num=10
    print(num/0)
except ZeroDivisionError:
    print("program executed")
# Out:
# program executed

# %%
try:
    num=10
    print(num/0)
except ZeroDivisionError:
    print("cannot divideby zero")
# Out:
# cannot divideby zero

# %%
try:
    file =open("xyz.txt","r")
except FileNotFoundError:
    print("file Doesn't exist")
# Out:
# file Doesn't exist

# %%
try:
    age=int(input("Enter the age"))
except ValueError:
    print("enter the valid age")
# Out:
# Enter the age 20

# %%
try:
    age=int(input("Enter the age"))
except ValueError:
    print("enter the valid age")

# %%
try: 
    swim=int(input("Enter the swim"))
except ValueError:
    print("enter the valid swim")
# Out:
# Enter the swim 390
