# %%
name="swathi"
def greet():
    print("Hello", name)
greet()
# Out:
# Hello swathi

# %%
breakfast="watermelon"
def eat():
    print("iam ready to eat",breakfast)
eat()
# Out:
# iam ready to eat watermelon

# %%
def add(a,b):
    return a+b
print(add(100,200))
# Out:
# 300

# %%
def sub (a,b):
    return a-b
print(sub(100,200))
# Out:
# -100

# %%
def add (a,s,d=0):
   return a+s+d
print(add(100,200))
print(add(100,200,300))
# Out:
# 300
# 600

# %%
def multiplication(a,s,d=0):
    return a*s*d
print(multiplication(100,200))
print(multiplication(100,200,300))
# Out:
# 0
# 6000000

# %%
def subraction (a,s,d=0):
    return a-s-d
print(subraction(100,200))
print(subraction(100,200,300))
# Out:
# -100
# -400

# %%
def add(*numbers):
    print(sum(numbers))
add (10,20)
add (10,20,30)
add (10,20,30,40)
add(10,20,30,40,50)
# Out:
# 30
# 60
# 100
# 150

# %%
def students(*marks):
    print(sum(marks))
add(200,300)
add (200,300,400)
add (200,300,400,500)
add (200,300,400,500,)
# Out:
# 500
# 900
# 1400
# 1400
